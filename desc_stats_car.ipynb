# %%
import numpy as np

# %%
age=np.array([8,19,21,21,20,20,20,28,26,29,50])#outlier
age
# Out:
# array([ 8, 19, 21, 21, 20, 20, 20, 28, 26, 29, 50])

# %%
np.mean(age)
# Out:
# np.float64(23.818181818181817)

# %%
np.median(age)
# Out:
# np.float64(21.0)

# %%
import pandas as pd

# %%
c=pd.read_csv("/content/quikr_car.csv")
c
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
c.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
c.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
c['Price']=c['Price'].astype('str')
c['Price']=c['Price'].str.replace(',',"")
c['Price']
# Out:
# 0              80000
# 1             425000
# 2      Ask For Price
# 3             325000
# 4             575000
#            ...
# 887           310000
# 888           260000
# 889           390000
# 890           180000
# 891           160000
# Name: Price, Length: 892, dtype: object

# %%
c['Price'].value_counts()
# Out:
# Price
# Ask For Price    35
# 250000           17
# 350000           14
# 180000           13
# 130000           12
#                  ..
# 1225000           1
# 68000             1
# 970000            1
# 860000            1
# 500001            1
# Name: count, Length: 274, dtype: int64

# %%
c=c[c['Price']!="Ask For Price"]
c
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 887                                      Ta       Tara  zest  310000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 3    28,000 kms    Petrol
# 4    36,000 kms    Diesel
# ...

# %%
c['Price'].value_counts()
# Out:
# Price
# 250000     17
# 350000     14
# 180000     13
# 130000     12
# 400000     12
#            ..
# 1225000     1
# 68000       1
# 970000      1
# 3100000     1
# 500001      1
# Name: count, Length: 273, dtype: int64

# %%
c['Price']=pd.to_numeric(c['Price'],errors='coerce')
c['Price']
# Out:
# /tmp/ipykernel_7096/2415530776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Price']=pd.to_numeric(c['Price'],errors='coerce')
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 887    310000
# 888    260000
# 889    390000
# 890    180000
# 891    160000
# Name: Price, Length: 857, dtype: int64

# %%
c["Price"].isnull().value_counts()
# Out:
# Price
# False    857
# Name: count, dtype: int64

# %%
c['kms_driven']=c['kms_driven'].astype('str')
c['kms_driven']=c['kms_driven'].str.replace(',',"")
c['kms_driven']
# Out:
# /tmp/ipykernel_7096/4118291747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven']=c['kms_driven'].astype('str')
# /tmp/ipykernel_7096/4118291747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven']=c['kms_driven'].str.replace(',',"")
# 0      45000 kms
# 1         40 kms
# 3      28000 kms
# 4      36000 kms
# 6      41000 kms
#          ...
# 887          nan
# 888    27000 kms
# 889    40000 kms
# 890       Petrol
# 891       Petrol
# ...

# %%
c['kms_driven']=c['kms_driven'].str.replace('kms',"")
c['kms_driven']
# Out:
# /tmp/ipykernel_7096/2683355489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven']=c['kms_driven'].str.replace('kms',"")
# 0      45000
# 1         40
# 3      28000
# 4      36000
# 6      41000
#         ...
# 887       nan
# 888    27000
# 889    40000
# 890    Petrol
# 891    Petrol
# Name: kms_driven, Length: 857, dtype: object

# %%
c['kms_driven']=c['kms_driven'].str.replace('Petrol',"")
c['kms_driven']
# Out:
# /tmp/ipykernel_7096/3681598931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven']=c['kms_driven'].str.replace('Petrol',"")
# 0      45000
# 1         40
# 3      28000
# 4      36000
# 6      41000
#         ...
# 887       nan
# 888    27000
# 889    40000
# 890
# 891
# Name: kms_driven, Length: 857, dtype: object

# %%
c["kms_driven"].isnull().value_counts()
# Out:
# kms_driven
# False    857
# Name: count, dtype: int64

# %%
c['kms_driven']=pd.to_numeric(c['kms_driven'],errors='coerce')
c['kms_driven']
# Out:
# /tmp/ipykernel_7096/1721160808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven']=pd.to_numeric(c['kms_driven'],errors='coerce')
# 0      45000.0
# 1         40.0
# 3      28000.0
# 4      36000.0
# 6      41000.0
#         ...
# 887        NaN
# 888    27000.0
# 889    40000.0
# 890        NaN
# 891        NaN
# Name: kms_driven, Length: 857, dtype: float64

# %%
c['kms_driven'].isnull().value_counts()
# Out:
# kms_driven
# False    817
# True      40
# Name: count, dtype: int64

# %%
c['kms_driven'].fillna(c['kms_driven'].mean(),inplace=True)
c['kms_driven']
# Out:
# /tmp/ipykernel_7096/3314336080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['kms_driven'].fillna(c['kms_driven'].mean(),inplace=True)
# 0      45000.00000
# 1         40.00000
# 3      28000.00000
# 4      36000.00000
# 6      41000.00000
#           ...
# 887    46250.71481
# 888    27000.00000
# 889    40000.00000
# 890    46250.71481
# 891    46250.71481
# Name: kms_driven, Length: 857, dtype: float64

# %%
c['kms_driven'].isnull().value_counts()
# Out:
# kms_driven
# False    857
# Name: count, dtype: int64

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        857 non-null    object
#  1   company     857 non-null    object
#  2   year        857 non-null    object
#  3   Price       857 non-null    int64
#  4   kms_driven  857 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.9+ KB

# %%
c['year'].unique()
# Out:
# array(['2007', '2006', '2014', '2012', '2013', '2016', '2015', '2010',
#        '2017', '2008', '2018', '2011', '2019', '2009', '2005', '2000',
#        '150k', 'TOUR', '2003', 'r 15', '2004', 'sale', '1995', 'ara)',
#        '2002', 'SELL', '2001', 'tion', 'odel', '2 bs', 'arry', 'o...',
#        'Zest', 'ture', 'emi', 'car', 'able', 'd...', 'SALE', 'sell',
#        'd Ex', 'n...', 'e...', 'go .', 'k...', 'o c4', 'zire', 'Sumo',
#        'cab', 'EV2', 'r...', 'zest'], dtype=object)

# %%
c=c[c['year'].str.isnumeric()]
c
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type
# 0     45000.00000    Petrol
# 1        40.00000    Diesel
# 3     28000.00000    Petrol
# ...

# %%
c['year'].unique()
# Out:
# array(['2007', '2006', '2014', '2012', '2013', '2016', '2015', '2010',
#        '2017', '2008', '2018', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
c['year']=c['year'].astype('int')
c
# Out:
# /tmp/ipykernel_7096/2515232722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['year']=c['year'].astype('int')
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   fuel_type   816 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 77.1+ KB

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
import scipy.stats as s
c['fuel_type'].mode()
# Out:
# 0    Petrol
# Name: fuel_type, dtype: object

# %%
d=pd.get_dummies(c['fuel_type'])
d
# Out:
#      Diesel    LPG  Petrol
# 0     False  False    True
# 1      True  False   False
# 3     False  False    True
# 4      True  False   False
# 6      True  False   False
# ..      ...    ...     ...
# 886   False  False    True
# 888    True  False   False
# 889    True  False   False
# 890   False  False   False
# 891   False  False   False
#
# [819 rows x 3 columns]

# %%
c=pd.concat([c,d],axis=1)
c
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type  Diesel    LPG  Petrol
# 0     45000.00000    Petrol   False  False    True
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   fuel_type   816 non-null    object
#  6   Diesel      819 non-null    bool
#  7   LPG         819 non-null    bool
#  8   Petrol      819 non-null    bool
# dtypes: bool(3), float64(1), int64(2), object(3)
# memory usage: 79.5+ KB

# %%
c.drop('fuel_type',axis=1,inplace=True)
c
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven  Diesel    LPG  Petrol
# 0     45000.00000   False  False    True
# 1        40.00000    True  False   False
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    float64
#  5   Diesel      819 non-null    bool
#  6   LPG         819 non-null    bool
#  7   Petrol      819 non-null    bool
# dtypes: bool(3), float64(1), int64(2), object(2)
# memory usage: 73.1+ KB

# %%
#measures of central tendency
c['Price'].mean()
# Out:
# np.float64(410960.40781440784)

# %%
c['Price'].median()
# Out:
# 299999.0

# %%
#measures of dispersion
c['Price'].std()
# Out:
# 474486.55635755765

# %%
c['Price'].var()
# Out:
# 225137492164.0537

# %%
import matplotlib.pyplot as plt

# %%
#measures of frequency
plt.hist(c['Price'],color='red')
plt.show()

# %%
# import numpy as np
# nd=np.random.normal(loc=0,scale=1,size=100000000)
# import pandas as pd
# n=pd.Series(nd)
# n.kurtosis()

# %%
c['Price'].kurt()
# Out:
# np.float64(106.9052207246824)

# %%
import seaborn as sns
sns.boxplot(c["Price"])
plt.show()

# %%
salaryA=[10,20,30,50,70,150]
np.mean(salaryA)
# Out:
# np.float64(55.0)

# %%
salaryB=[22,23,25,26,27,33,200]
np.mean(salaryB)
# Out:
# np.float64(50.857142857142854)

# %%
from scipy.stats import skew

# %%
sa=pd.Series(salaryA)
sa.skew()
# Out:
# np.float64(1.581456434921748)

# %%
sb=pd.Series(salaryB)
sb.skew()
# Out:
# np.float64(2.6297482766261733)

# %%
sns.histplot(salaryA,kde=True)
# Out:
# <Axes: ylabel='Count'>
